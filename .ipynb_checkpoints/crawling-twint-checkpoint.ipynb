# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# Configure
c = twint.Config()

c.Lang = "id"
c.Since = "2021-04-01"
c.Until = "2021-04-18"
c.Search = "vaksin covid-19"
c.Limit = 5000
c.Store_csv = True
c.Output = "dataset.csv"

# Run
twint.run.Search(c)
# Out:
# 1377047500108955648 2021-03-31 06:58:02 +0700 <Tsani51461769> Kepala Dinas Kesehatan Kabupaten Jayapura, Khairul Lie mengatakan program vaksinasi COVID-19 di Kabupaten Jayapura, Papua, telah menggunakan 8.100 dosis vaksin.  #DampakBaikOtsusPapua PON Papua Dorong UMKM  https://t.co/X4EYQ6LJDY
# 1377047375861018624 2021-03-31 06:57:33 +0700 <babe53591768> Kepala Dinas Kesehatan Kabupaten Jayapura, Khairul Lie mengatakan program vaksinasi COVID-19 di Kabupaten Jayapura, Papua, telah menggunakan 8.100 dosis vaksin.  #DampakBaikOtsusPapua PON Papua Dorong UMKM  https://t.co/ZZi57IPQJg
# 1377046978475925505 2021-03-31 06:55:58 +0700 <MyName_siapa> Kepala Badan Intelijen dan Keamanan (Kabaintelkam) Polri, Komjen Pol. Drs. Paulus Waterpauw berharap masyarakat Papua tidak menolak untuk disuntik vaksin sinovac (COVID-19) karena itu penting bagi kesehatan masyarakat sendiri. #DampakBaikOtsusPapua #PapuaIndonesia  https://t.co/Sz60Drdkaa
# ...
